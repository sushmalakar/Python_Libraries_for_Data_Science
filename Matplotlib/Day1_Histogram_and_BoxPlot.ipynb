# %% [markdown]
# ## Making Histogram

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data=[1,3,3,3,3,9,9,4,4,8,8,8,6,7] # creating a data

# %%
plt.hist(data, color="b") # plotting a histogram with hist function
plt.show()

# %% [markdown]
# ## Adding the bins

# %%
plt.figure(figsize=(9,2))
plt.hist(data, color="g", bins=3) # plotting a histogram with hist function
plt.show()

# %% [markdown]
# ## Working with a real world data

# %%
import pandas as pd

# %%
iris_df = pd.read_csv('Data_Sets/Iris.csv')

# %%
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.hist(iris_df['SepalLengthCm'], bins=30, color="g")
plt.title("Plotting Sepallength")
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(1,4,2)
plt.hist(iris_df['SepalWidthCm'], bins=30, color="r")
plt.title("Plotting Sepal Width")
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(1,4,3)
plt.hist(iris_df['PetalLengthCm'], bins=30, color="b")
plt.title("Plotting Petal Length")
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(1,4,4)
plt.hist(iris_df['PetalLengthCm'], bins=30, color="pink")
plt.title("Plotting Petal Width")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Creating a Box Plot

# %%
one=[1,2,3,4,5,6,7,8,9]
two=[1,2,3,4,5,4,3,2,1]
three=[6,7,8,9,8,7,6,5,4]
data=list([one,two,three])
plt.boxplot(data)
plt.show()
